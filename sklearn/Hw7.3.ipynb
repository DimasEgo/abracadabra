# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
X, y = load_diabetes(return_X_y=True)

# %% [markdown]
# Regressor with default test_size(0,25)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True)
regressor = LinearRegression().fit(X_train, y_train)

# %%
regressor.score(X_test, y_test)
# Out:
# 0.5751140663329377

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([188.43178744,  53.20879449, 154.56369515, 151.56638769,
#        165.22581428,  85.06828059, 244.79542874, 125.8727574 ,
#        142.93656776, 163.932896  ,  90.58581098, 232.58643928,
#         54.94297321, 159.68074478,  71.17781293, 214.93869231,
#        224.00426913,  81.91914267, 222.76767323, 226.08832573,
#        162.2821339 ,  59.71409159, 120.72563286, 184.5483607 ,
#         49.0306257 , 176.2269843 , 177.42448544, 187.34670515,
#        229.23300892, 140.04879163,  89.41097707, 193.51959037,
#        139.02459384, 202.3446008 ,  99.58662646,  80.08665534,
#        225.21471432, 185.2603158 , 217.57940832,  44.8603529 ,
#        115.78165379, 137.04171823, 150.95233561, 183.78579596,
#        163.19338637,  95.33298779,  61.6956267 , 122.28126157,
#        229.11925493, 209.12018622, 136.24872253, 163.8486021 ,
#        163.13275485, 184.48439393, 120.68650515,  83.81212247,
#        146.07772905, 137.86479687, 161.31463015,  98.58234993,
#        101.8829207 , 149.63873648, 165.55577663, 189.97512723,
#        129.5108163 , 252.2795947 , 125.04408276, 104.05068878,
#        226.45845411, 137.78926882, 157.3508506 , 182.24901198,
#        137.83079094, 185.51801583, 201.46176129, 129.8120846 ,
#        210.05756363,  91.05372643,  97.39677758, 123.71848673,
#        136.18878123, 189.20155797, 233.71091462, 147.3645609 ,
#        272.99527923,  80.19475207, 154.40119625,  90.50279983,
#        283.26476827, 229.44085087, 112.44228697,  94.73349015,
#        144.16213466, 147.83765918,  57.49979313,  71.77548705,
#        135.4449411 , 191.5695959 , 132.39674145, 264.55047963,
#        168.08983743,  47.89814821,  86.97171915, 223.78553745,
#        153.87906034, 247.10252498, 249.19648733, 101.43979864,
#        112.86364076, 121.00182069, 120.06236646])

# %%
y_test
# Out:
# array([233.,  65., 156., 246., 206.,  92., 243., 139., 185., 235.,  74.,
#        270.,  70., 245., 134., 268., 225.,  77., 257., 268., 151.,  43.,
#        144., 229.,  72., 124., 263., 178., 280.,  93.,  54., 191., 142.,
#        109.,  94.,  51., 155., 170., 332., 116., 102., 202., 209.,  68.,
#        262., 101.,  77.,  68., 275., 202., 187., 109., 252., 232.,  53.,
#         60., 214., 103., 127.,  47.,  72., 134., 225., 122., 131., 273.,
#        140., 135., 128., 190., 131., 161.,  40., 202., 265.,  74., 249.,
#        113., 137.,  97., 219.,  78., 261., 302., 281.,  59., 100., 115.,
#        230., 321.,  72.,  69.,  25.,  85.,  57.,  51.,  90., 221., 124.,
#        346., 181.,  47.,  96., 208., 198., 277., 306.,  84.,  61., 132.,
#        182.])

# %%
metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 41.987697555091856

# %%
#Regressor mean absolute error = 44.5

# %% [markdown]
# Regressor with test_size 0,33

# %%
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X, y, test_size=0.33, shuffle=True)
regressor_2 = LinearRegression().fit(X_train_2, y_train_2)
regressor_2.score(X_test_2, y_test_2)
# Out:
# 0.45871434841189174

# %%
#Regressor score went down with test_size 0.33

# %%
y_pred_2 = regressor_2.predict(X_test_2)
y_pred_2
# Out:
# array([179.49467647, 113.08317371, 163.62312676, 206.45761406,
#         64.7794357 , 190.26246506, 178.13253766, 180.18600058,
#        155.7632263 , 259.00456185, 222.48001755, 197.65873734,
#         58.93073255, 165.47707892,  59.30388267, 214.53809202,
#        113.76799127,  80.36359649, 185.53364851, 217.89260363,
#         87.17295355, 217.2522658 , 138.81662156, 234.74052068,
#        152.00935347, 150.0889967 , 150.10987985, 201.24624427,
#        195.21169938,  89.19192933, 128.39496419, 164.52909527,
#        131.06645808, 164.01478721, 160.80445621,  91.76959681,
#        224.94649352, 136.12970968, 119.21021162, 117.08156532,
#        248.8022585 , 182.83950175, 119.98147616, 169.05685833,
#        189.9501634 , 198.57948204,  80.09451702, 181.6444694 ,
#        117.84808201, 144.131326  , 219.40892586, 200.50031425,
#        254.04828216, 176.393304  , 208.29897703, 148.87650412,
#        104.03629911,  71.14963664, 195.4906818 , 103.30571336,
#        247.56185377, 192.70104046, 216.19013917, 278.73826565,
#        131.04286009, 207.85069008, 165.05227944, 135.91999077,
#         82.80546518, 158.80714989, 132.1682987 , 264.94138699,
#        235.37720647, 192.07707741,  59.98086253, 217.25463002,
#         66.26452273, 189.43800654,  79.1394612 , 151.03789516,
#         85.37294716, 126.53527533, 134.6195697 , 173.56060335,
#        234.6287258 , 261.4033096 ,  82.66178822, 105.70349492,
#        233.93235717, 147.44062985, 185.52787409, 199.46712766,
#        164.43570212, 124.74230836,  99.31313347, 158.53852666,
#        106.44257371,  98.34016087, 226.8088673 , 144.51773983,
#        267.64251872, 160.56064656, 150.63310179, 205.6628678 ,
#        214.1375641 , 228.92509891, 108.99577276, 182.77585919,
#         75.71610179,  71.17519009,  91.08880794, 152.71485023,
#        257.84181845, 153.20007722,  80.69717626, 171.48027565,
#         69.36955442, 251.89498058, 114.17607523, 147.28855982,
#        192.07473799, 254.22547712,  90.44865392, 154.51053947,
#        120.9422729 , 108.54778237, 144.47207482, 112.82762167,
#        119.38171083, 115.11987409, 173.25716039,  90.87925383,
#        122.24729333, 210.18541977, 235.35972119,  59.32904301,
#        152.42291051, 118.69090994,  88.1937385 , 148.09010314,
#        155.77743579, 142.06993923, 147.67412441, 246.75574432,
#        219.75632911, 127.68930424])

# %%
y_test_2
# Out:
# array([174., 102., 129., 173.,  43., 161.,  77.,  91., 150., 281., 275.,
#        122.,  63., 245.,  39.,  52.,  97.,  55.,  66., 220.,  37., 249.,
#        103., 257., 202., 182.,  81., 137., 175.,  49., 113., 220., 178.,
#        178., 200.,  69., 173.,  49.,  68., 111., 272., 171.,  53.,  86.,
#        283., 233., 104.,  90., 200., 142., 310., 186., 310., 139., 265.,
#         95., 118.,  75., 142.,  47., 264.,  67., 275., 243.,  65., 150.,
#        200., 162.,  77., 100., 178., 308., 232., 178.,  52., 202.,  96.,
#        197.,  89.,  88.,  55., 111., 135., 151.,  99., 310.,  65., 125.,
#        155.,  40.,  85., 163., 185.,  64.,  31., 237., 108.,  88., 296.,
#        214., 303., 246.,  61., 292., 297., 225.,  69., 144., 138.,  75.,
#         51.,  25., 336.,  85., 134., 184.,  72., 274., 107.,  83., 101.,
#        277., 181.,  85.,  61.,  63., 182., 199., 179.,  71.,  58.,  64.,
#         87., 109., 128.,  48., 168., 142.,  42., 190.,  73., 187., 219.,
#        132., 180.,  84.])

# %%
metrics.mean_absolute_error(y_test_2, y_pred_2)
# Out:
# 47.38311407964614

# %%
#Regressor mean absolute error is greater with test_size 0.33
